# %%
#import libraries
import pandas as pd
import pymongo
import psycopg2
from sqlalchemy import create_engine
from sqlalchemy import text
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Create Connection to postgres

# %%
conn = psycopg2.connect(database="postgres", user='postgres', password='postgres', host='127.0.0.1', port='5432')
conn.autocommit = True

# %% [markdown]
# ### Create Database in postgres

# %%
cursor = conn.cursor()

sql = '''CREATE database beer_db''';

cursor.execute(sql)
print("Database created successfully........")

#Closing the connection
conn.close()
# Out:
# Database created successfully........

# %% [markdown]
# ## Store CSV into DataFrame

# %%
csv_file = "../ETL-Project/data/archive/beers.csv"
beers_df = pd.read_csv(csv_file)
beers_df.head()
# Out:
#    Unnamed: 0    abv  ibu    id                 name  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0

# %%
csv_file = "../ETL-Project/data/archive/breweries.csv"
breweries_df = pd.read_csv(csv_file)
breweries_df.head()
# Out:
#    Unnamed: 0                       name           city state
# 0           0         NorthGate Brewing     Minneapolis    MN
# 1           1  Against the Grain Brewery     Louisville    KY
# 2           2   Jack's Abby Craft Lagers     Framingham    MA
# 3           3  Mike Hess Brewing Company      San Diego    CA
# 4           4    Fort Point Beer Company  San Francisco    CA

# %%
breweries_df.rename(columns = {'Unnamed: 0':'brewery_id', 'name':'brewery_name'}, inplace = True) 
breweries_df.head()
# Out:
#    brewery_id               brewery_name           city state
# 0           0         NorthGate Brewing     Minneapolis    MN
# 1           1  Against the Grain Brewery     Louisville    KY
# 2           2   Jack's Abby Craft Lagers     Framingham    MA
# 3           3  Mike Hess Brewing Company      San Diego    CA
# 4           4    Fort Point Beer Company  San Francisco    CA

# %%
breweries_df.set_index("brewery_id")
# Out:
#                              brewery_name           city state
# brewery_id
# 0                      NorthGate Brewing     Minneapolis    MN
# 1               Against the Grain Brewery     Louisville    KY
# 2                Jack's Abby Craft Lagers     Framingham    MA
# 3               Mike Hess Brewing Company      San Diego    CA
# 4                 Fort Point Beer Company  San Francisco    CA
# ...                                   ...            ...   ...
# 553                   Covington Brewhouse      Covington    LA
# 554                       Dave's Brewfarm         Wilson    WI
# 555                 Ukiah Brewing Company          Ukiah    CA
# 556               Butternuts Beer and Ale  Garrattsville    NY
# 557         Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 3 columns]

# %%
breweries_df.state = breweries_df.state.str.lstrip()
breweries_df
# Out:
#      brewery_id                   brewery_name           city state
# 0             0             NorthGate Brewing     Minneapolis    MN
# 1             1      Against the Grain Brewery     Louisville    KY
# 2             2       Jack's Abby Craft Lagers     Framingham    MA
# 3             3      Mike Hess Brewing Company      San Diego    CA
# 4             4        Fort Point Beer Company  San Francisco    CA
# ..          ...                            ...            ...   ...
# 553         553            Covington Brewhouse      Covington    LA
# 554         554                Dave's Brewfarm         Wilson    WI
# 555         555          Ukiah Brewing Company          Ukiah    CA
# 556         556        Butternuts Beer and Ale  Garrattsville    NY
# 557         557  Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 4 columns]

# %%
#drop columns in beer_df
beers_df = beers_df.drop(columns=['Unnamed: 0', 'ibu'])
#beers_df.head()

# %%
beers_df.rename(columns = {'id':'beer_id', 'name':'beer_name'}, inplace = True)

# %%
beers_df.set_index("beer_id")
# Out:
#            abv             beer_name                           style  \
# beer_id
# 1436     0.050              Pub Beer             American Pale Lager
# 2265     0.066           Devil's Cup         American Pale Ale (APA)
# 2264     0.071   Rise of the Phoenix                    American IPA
# 2263     0.090              Sinister  American Double / Imperial IPA
# 2262     0.075         Sex and Candy                    American IPA
# ...        ...                   ...                             ...
# 928      0.067             Belgorado                     Belgian IPA
# 807      0.052         Rail Yard Ale        American Amber / Red Ale
# 620      0.055       B3K Black Lager                     Schwarzbier
# 145      0.055   Silverback Pale Ale         American Pale Ale (APA)
# 84       0.052  Rail Yard Ale (2009)        American Amber / Red Ale
#
#          brewery_id  ounces
# beer_id
# 1436            408    12.0
# 2265            177    12.0
# 2264            177    12.0
# 2263            177    12.0
# 2262            177    12.0
# ...             ...     ...
# 928             424    12.0
# 807             424    12.0
# 620             424    12.0
# 145             424    12.0
# 84              424    12.0
#
# [2410 rows x 5 columns]

# %% [markdown]
# ## Build Schema in SQL

# %%
conn = psycopg2.connect(database="beer_db", user='postgres', password='postgres', host='127.0.0.1', port='5432')
conn.autocommit = True
cursor = conn.cursor()

# %%
schema_sql = open('Schema Build.sql','r')
cursor.execute(schema_sql.read())
conn.close()
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# <ipython-input-12-db4f0032e7d2> in <module>
#       1 schema_sql = open('Schema Build.sql','r')
# ----> 2 cursor.execute(schema_sql.read())
#       3 conn.close()
#
# DuplicateTable: relation "brewery" already exists

# %% [markdown]
# ## Create connection for Load operation

# %%
connection_string = "postgres:postgres@localhost:5432/beer_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['brewery', 'beers']

# %% [markdown]
# ### Load the DF into Postgres

# %%
breweries_df.to_sql(name='brewery', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UniqueViolation: duplicate key value violates unique constraint "brewery_pkey"
# DETAIL:  Key (brewery_id)=(0) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-116-e1b0e08dd7f0> in <module>
# ----> 1 breweries_df.to_sql(name='brewery', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1128             distilled_params,
#    1129             compiled_sql,
# -> 1130             distilled_params,
#    1131         )
#    1132         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315         except BaseException as e:
#    1316             self._handle_dbapi_exception(
# -> 1317                 e, statement, parameters, cursor, context
#    1318             )
#    1319
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509             elif should_wrap:
#    1510                 util.raise_(
# -> 1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#    1513             else:
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#    1259             elif not parameters and context.no_parameters:
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "brewery_pkey"
# DETAIL:  Key (brewery_id)=(0) already exists.
#
# [SQL: INSERT INTO brewery (brewery_id, brewery_name, city, state) VALUES (%(brewery_id)s, %(brewery_name)s, %(city)s, %(state)s)]
# [parameters: ({'brewery_id': 0, 'brewery_name': 'NorthGate Brewing ', 'city': 'Minneapolis', 'state': 'MN'}, {'brewery_id': 1, 'brewery_name': 'Against the Grain Brewery', 'city': 'Louisville', 'state': 'KY'}, {'brewery_id': 2, 'brewery_name': "Jack's Abby Craft Lagers", 'city': 'Framingham', 'state': 'MA'}, {'brewery_id': 3, 'brewery_name': 'Mike Hess Brewing Company', 'city': 'San Diego', 'state': 'CA'}, {'brewery_id': 4, 'brewery_name': 'Fort Point Beer Company', 'city': 'San Francisco', 'state': 'CA'}, {'brewery_id': 5, 'brewery_name': 'COAST Brewing Company', 'city': 'Charleston', 'state': 'SC'}, {'brewery_id': 6, 'brewery_name': 'Great Divide Brewing Company', 'city': 'Denver', 'state': 'CO'}, {'brewery_id': 7, 'brewery_name': 'Tapistry Brewing', 'city': 'Bridgman', 'state': 'MI'}  ... displaying 10 of 558 total bound parameter sets ...  {'brewery_id': 556, 'brewery_name': 'Butternuts Beer and Ale', 'city': 'Garrattsville', 'state': 'NY'}, {'brewery_id': 557, 'brewery_name': 'Sleeping Lady Brewing Company', 'city': 'Anchorage', 'state': 'AK'})]
# (Background on this error at: http://sqlalche.me/e/13/gkpj)

# %%
beers_df.to_sql(name='beers', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UniqueViolation: duplicate key value violates unique constraint "beers_pkey"
# DETAIL:  Key (beer_id)=(1436) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-117-e13459373193> in <module>
# ----> 1 beers_df.to_sql(name='beers', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1128             distilled_params,
#    1129             compiled_sql,
# -> 1130             distilled_params,
#    1131         )
#    1132         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315         except BaseException as e:
#    1316             self._handle_dbapi_exception(
# -> 1317                 e, statement, parameters, cursor, context
#    1318             )
#    1319
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509             elif should_wrap:
#    1510                 util.raise_(
# -> 1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#    1513             else:
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#    1259             elif not parameters and context.no_parameters:
#
# ~\anaconda3\envs\VirCondaEnv\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "beers_pkey"
# DETAIL:  Key (beer_id)=(1436) already exists.
#
# [SQL: INSERT INTO beers (abv, beer_id, beer_name, style, brewery_id, ounces) VALUES (%(abv)s, %(beer_id)s, %(beer_name)s, %(style)s, %(brewery_id)s, %(ounces)s)]
# [parameters: ({'abv': 0.05, 'beer_id': 1436, 'beer_name': 'Pub Beer', 'style': 'American Pale Lager', 'brewery_id': 408, 'ounces': 12.0}, {'abv': 0.066, 'beer_id': 2265, 'beer_name': "Devil's Cup", 'style': 'American Pale Ale (APA)', 'brewery_id': 177, 'ounces': 12.0}, {'abv': 0.071, 'beer_id': 2264, 'beer_name': 'Rise of the Phoenix', 'style': 'American IPA', 'brewery_id': 177, 'ounces': 12.0}, {'abv': 0.09, 'beer_id': 2263, 'beer_name': 'Sinister', 'style': 'American Double / Imperial IPA', 'brewery_id': 177, 'ounces': 12.0}, {'abv': 0.075, 'beer_id': 2262, 'beer_name': 'Sex and Candy', 'style': 'American IPA', 'brewery_id': 177, 'ounces': 12.0}, {'abv': 0.077, 'beer_id': 2261, 'beer_name': 'Black Exodus', 'style': 'Oatmeal Stout', 'brewery_id': 177, 'ounces': 12.0}, {'abv': 0.045, 'beer_id': 2260, 'beer_name': 'Lake Street Express', 'style': 'American Pale Ale (APA)', 'brewery_id': 177, 'ounces': 12.0}, {'abv': 0.065, 'beer_id': 2259, 'beer_name': 'Foreman', 'style': 'American Porter', 'brewery_id': 177, 'ounces': 12.0}  ... displaying 10 of 2410 total bound parameter sets ...  {'abv': 0.055, 'beer_id': 145, 'beer_name': 'Silverback Pale Ale', 'style': 'American Pale Ale (APA)', 'brewery_id': 424, 'ounces': 12.0}, {'abv': 0.052000000000000005, 'beer_id': 84, 'beer_name': 'Rail Yard Ale (2009)', 'style': 'American Amber / Red Ale', 'brewery_id': 424, 'ounces': 12.0})]
# (Background on this error at: http://sqlalche.me/e/13/gkpj)

# %% [markdown]
# ### Dispose of the Connection to the Database

# %%
engine.dispose()

# %%
sql = conn.cursor()

# %%
sql.execute("SELECT bw.brewery_name, bw.state, br.beer_name FROM BEERS br INNER JOIN BREWERY bw ON br.BREWERY_ID = bw.BREWERY_ID ORDER BY bw.state ASC;")
result_data = sql.fetchall()

print(result_data)
# Out:
# [('King Street Brewing Company', ' AK', 'King Street IPA'), ('Kenai River Brewing Company', ' AK', 'Skilak Scottish Ale'), ('Broken Tooth Brewing Company', ' AK', 'Fairweather IPA'), ('Broken Tooth Brewing Company', ' AK', 'Chugach Session Ale'), ('Broken Tooth Brewing Company', ' AK', 'Polar Pale Ale'), ('Broken Tooth Brewing Company', ' AK', 'Northern Lights Amber Ale'), ('Midnight Sun Brewing Company', ' AK', 'Snowshoe White Ale'), ('Midnight Sun Brewing Company', ' AK', 'Pleasure Town IPA'), ('Midnight Sun Brewing Company', ' AK', 'Pleasure Town'), ('King Street Brewing Company', ' AK', 'King Street Pilsner'), ('King Street Brewing Company', ' AK', 'King Street Blonde Ale'), ('Alaskan Brewing Company', ' AK', 'Alaskan Amber'), ('King Street Brewing Company', ' AK', 'Amber Ale'), ('Sleeping Lady Brewing Company', ' AK', 'Urban Wilderness Pale Ale'), ('King Street Brewing Company', ' AK', 'King Street Hefeweizen'), ('Midnight Sun Brewing Company', ' AK', 'Sockeye Red IPA'), ('Kenai River Brewing Company', ' AK', 'Peninsula Brewers Reserve (PBR)'), ('Kenai River Brewing Company', ' AK', 'Skilak Scottish Ale (2011)'), ('Kenai River Brewing Company', ' AK', 'Sunken Island IPA'), ('Alaskan Brewing Company', ' AK', 'Freeride APA'), ('Midnight Sun Brewing Company', ' AK', 'Kodiak Brown Ale'), ('Denali Brewing Company', ' AK', 'Single Engine Red'), ('Denali Brewing Company', ' AK', 'Twister Creek India Pale Ale'), ('Denali Brewing Company', ' AK', 'Mother Ale'), ('Denali Brewing Company', ' AK', 'Chuli Stout'), ('Back Forty Beer Company', ' AL', 'Naked Pig Pale Ale'), ('Good People Brewing Company', ' AL', 'Good People American Brown Ale'), ('Good People Brewing Company', ' AL', 'Good People IPA'), ('Good People Brewing Company', ' AL', 'Coffee Oatmeal Stout'), ('Good People Brewing Company', ' AL', 'Snake Handler Double IPA'), ('Good People Brewing Company', ' AL', 'Good People Pale Ale'), ('Straight to Ale', ' AL', 'Monkeynaut IPA'), ('Back Forty Beer Company', ' AL', 'Truck Stop Honey Brown Ale'), ('Straight to Ale', ' AL', 'Sand Island Lighthouse'), ('Straight to Ale', ' AL', 'Lily Flagg Milk Stout'), ('Core Brewing & Distilling Company', ' AR', 'Behemoth'), ('Core Brewing & Distilling Company', ' AR', 'Core Oatmeal Stout'), ('Core Brewing & Distilling Company', ' AR', 'Arkansas Red'), ('Core Brewing & Distilling Company', ' AR', 'Core ESB'), ('Ozark Beer Company', ' AR', 'Ozark American Pale Ale'), ('Borderlands Brewing Company', ' AZ', 'Noche Dulce'), ('Lumberyard Brewing Company', ' AZ', 'Lumberyard Red Ale'), ('Lumberyard Brewing Company', ' AZ', 'Lumberyard IPA'), ('Lumberyard Brewing Company', ' AZ', 'Lumberyard Pilsner'), ('Lumberyard Brewing Company', ' AZ', 'Knotty Pine'), ('Prescott Brewing Company', ' AZ', 'Ponderosa IPA'), ('Prescott Brewing Company', ' AZ', 'Liquid Amber Ale'), ('Four Peaks Brewing Company', ' AZ', 'Four Peaks Peach Ale'), ('Mogollon Brewing Company', ' AZ', 'Wapiti Amber Ale'), ('Barrio Brewing Company', ' AZ', 'Barrio Blanco'), ('Barrio Brewing Company', ' AZ', 'Barrio Tucson Blonde'), ('Phoenix Ale Brewery', ' AZ', 'Camelback'), ('SanTan Brewing Company', ' AZ', 'Winter Warmer (Vault Series)'), ('SanTan Brewing Company', ' AZ', 'Count Hopula (Vault Series)'), ('SanTan Brewing Company', ' AZ', 'Oktoberfest'), ('SanTan Brewing Company', ' AZ', 'SunSpot Golden Ale'), ('SanTan Brewing Company', ' AZ', 'I.W.A. (2011)'), ('SanTan Brewing Company', ' AZ', 'Supermonk I.P.A.'), ('SanTan Brewing Company', ' AZ', 'Epicenter Amber Ale'), ('SanTan Brewing Company', ' AZ', 'SanTan HefeWeizen'), ('SanTan Brewing Company', ' AZ', 'Hop Shock IPA'), ('SanTan Brewing Company', ' AZ', 'Sex Panther (2014)'), ('SanTan Brewing Company', ' AZ', 'Devil’s Ale'), ('SanTan Brewing Company', ' AZ', 'Rail Slide Imperial Spiced Ale'), ('SanTan Brewing Company', ' AZ', 'Mr. Pineapple'), ('SanTan Brewing Company', ' AZ', 'American Idiot Ale (2012)'), ('SanTan Brewing Company', ' AZ', 'Hop Shock IPA (2010)'), ('SanTan Brewing Co ...

# %%
col_names = []
for c in sql.description:
    col_names.append(c[0])

# %%
brewery_and_state_df = pd.DataFrame(result_data, columns=(col_names))
brewery_and_state_df
# Out:
#                       brewery_name state              beer_name
# 0      King Street Brewing Company    AK        King Street IPA
# 1      Kenai River Brewing Company    AK    Skilak Scottish Ale
# 2     Broken Tooth Brewing Company    AK        Fairweather IPA
# 3     Broken Tooth Brewing Company    AK    Chugach Session Ale
# 4     Broken Tooth Brewing Company    AK         Polar Pale Ale
# ...                            ...   ...                    ...
# 2405    Wind River Brewing Company    WY  Wind River Blonde Ale
# 2406   Snake River Brewing Company    WY        Monarch Pilsner
# 2407   Snake River Brewing Company    WY     Snow King Pale Ale
# 2408   Snake River Brewing Company    WY           Zonker Stout
# 2409   Snake River Brewing Company    WY       OB-1 Organic Ale
#
# [2410 rows x 3 columns]

# %%
sql.execute("SELECT br.style, br.brewery_id FROM BEERS br ORDER BY br.style ASC;")
result_data = sql.fetchall()

print(result_data)
# Out:
# [('Abbey Single Ale', 57), ('Abbey Single Ale', 57), ('Altbier', 25), ('Altbier', 122), ('Altbier', 490), ('Altbier', 268), ('Altbier', 144), ('Altbier', 395), ('Altbier', 364), ('Altbier', 71), ('Altbier', 122), ('Altbier', 270), ('Altbier', 268), ('Altbier', 200), ('Altbier', 121), ('American Adjunct Lager', 229), ('American Adjunct Lager', 131), ('American Adjunct Lager', 131), ('American Adjunct Lager', 131), ('American Adjunct Lager', 129), ('American Adjunct Lager', 229), ('American Adjunct Lager', 129), ('American Adjunct Lager', 131), ('American Adjunct Lager', 134), ('American Adjunct Lager', 38), ('American Adjunct Lager', 131), ('American Adjunct Lager', 233), ('American Adjunct Lager', 473), ('American Adjunct Lager', 134), ('American Adjunct Lager', 134), ('American Adjunct Lager', 131), ('American Adjunct Lager', 131), ('American Adjunct Lager', 155), ('American Amber / Red Ale', 150), ('American Amber / Red Ale', 183), ('American Amber / Red Ale', 380), ('American Amber / Red Ale', 487), ('American Amber / Red Ale', 219), ('American Amber / Red Ale', 201), ('American Amber / Red Ale', 530), ('American Amber / Red Ale', 209), ('American Amber / Red Ale', 209), ('American Amber / Red Ale', 43), ('American Amber / Red Ale', 549), ('American Amber / Red Ale', 289), ('American Amber / Red Ale', 353), ('American Amber / Red Ale', 220), ('American Amber / Red Ale', 100), ('American Amber / Red Ale', 161), ('American Amber / Red Ale', 260), ('American Amber / Red Ale', 85), ('American Amber / Red Ale', 267), ('American Amber / Red Ale', 438), ('American Amber / Red Ale', 230), ('American Amber / Red Ale', 551), ('American Amber / Red Ale', 397), ('American Amber / Red Ale', 536), ('American Amber / Red Ale', 500), ('American Amber / Red Ale', 221), ('American Amber / Red Ale', 497), ('American Amber / Red Ale', 155), ('American Amber / Red Ale', 155), ('American Amber / Red Ale', 171), ('American Amber / Red Ale', 229), ('American Amber / Red Ale', 362), ('American Amber / Red Ale', 256), ('American Amber / Red Ale', 182), ('American Amber / Red Ale', 182), ('American Amber / Red Ale', 265), ('American Amber / Red Ale', 294), ('American Amber / Red Ale', 391), ('American Amber / Red Ale', 79), ('American Amber / Red Ale', 158), ('American Amber / Red Ale', 375), ('American Amber / Red Ale', 228), ('American Amber / Red Ale', 410), ('American Amber / Red Ale', 80), ('American Amber / Red Ale', 92), ('American Amber / Red Ale', 496), ('American Amber / Red Ale', 80), ('American Amber / Red Ale', 152), ('American Amber / Red Ale', 115), ('American Amber / Red Ale', 488), ('American Amber / Red Ale', 298), ('American Amber / Red Ale', 424), ('American Amber / Red Ale', 491), ('American Amber / Red Ale', 374), ('American Amber / Red Ale', 140), ('American Amber / Red Ale', 171), ('American Amber / Red Ale', 203), ('American Amber / Red Ale', 330), ('American Amber / Red Ale', 485), ('American Amber / Red Ale', 60), ('American Amber / Red Ale', 241), ('American Amber / Red Ale', 66), ('American Amber / Red Ale', 93), ('American Amber / Red Ale', 91), ('American Amber / Red Ale', 552), ('American Amber / Red Ale', 124), ('American Amber / Red Ale', 472), ('American Amber / Red Ale', 253), ('American Amber / Red Ale', 175), ('American Amber / Red Ale', 365), ('American Amber / Red Ale', 355), ('American Amber / Red Ale', 212), ('American Amber / Red Ale', 63), ('American Amber / Red Ale', 360), ('American Amber / Red Ale', 63), ('American Amber / Red Ale', 63), ('American Amber / Red Ale', 102), ('American Amber / Red Ale', 30), ('American Amber / Red Ale', 235), ('American Amber / Red Ale', 84), ('American Amber / Red Ale', 534), ('American Amber / Red Ale', 548), ('American Amber / Red Ale', 93), ('American Amber / Red Ale', 139), ('American Amber / Red Ale', 97), ('American Amber / Red Ale', 101), ('American Amber / Red Ale', 11), ('American Amber / Red Ale', 318), ('American Amber / Red Ale', 101), ('American Amber / Red Al ...

# %%
col_names = []
for c in sql.description:
    col_names.append(c[0])
    col_names2.append(c[0])

# %%
beer_styles_df = pd.DataFrame(result_data, columns=(col_names))
beer_styles_df
# Out:
#                  style  brewery_id
# 0     Abbey Single Ale          57
# 1     Abbey Single Ale          57
# 2              Altbier          25
# 3              Altbier         122
# 4              Altbier         490
# ...                ...         ...
# 2405              None         160
# 2406              None         166
# 2407              None          29
# 2408              None          66
# 2409              None         166
#
# [2410 rows x 2 columns]

# %% [markdown]
# ## Bewery Count by State Bar Graph

# %%
brewery_state_count_df= brewery_and_state_df['state'].value_counts()
brewery_state_count_df.head(10)
# Out:
#  CO    265
#  CA    183
#  MI    162
#  IN    139
#  TX    130
#  OR    125
#  PA    100
#  IL     91
#  WI     87
#  MA     82
# Name: state, dtype: int64

# %%
plt.figure(figsize=(10,12))
sns.barplot(y=brewery_state_count_df.index, x=brewery_state_count_df.values)
plt.title('Number of Breweries by State')
plt.xlabel('Number of Breweries')
plt.ylabel('State')
plt.yticks(rotation='horizontal')
plt.show()

# %% [markdown]
# ## Most Popular Beer Style Bar Graph

# %%
beer_styles_count_df= beer_styles_df['style'].value_counts()

beer_styles_count_df.head(10)
# Out:
# American IPA                      424
# American Pale Ale (APA)           245
# American Amber / Red Ale          133
# American Blonde Ale               108
# American Double / Imperial IPA    105
# American Pale Wheat Ale            97
# American Brown Ale                 70
# American Porter                    68
# Saison / Farmhouse Ale             52
# Witbier                            51
# Name: style, dtype: int64

# %%
plt.figure(figsize=(10,12))
sns.barplot(y=beer_styles_count_df.nlargest(20).index, x=beer_styles_count_df.nlargest(20).values)
plt.title('Top 20 Most Popluar Beer Styles')
plt.xlabel('Number of Beers')
plt.ylabel('Beer Style')
plt.yticks(rotation='horizontal')
plt.show()

# %%
conn.close()
